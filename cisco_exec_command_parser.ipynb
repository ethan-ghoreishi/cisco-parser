# %%
from netmiko import ConnectHandler
import re
import numpy as np
# import nltk
import os
import string
import random
import re

# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# %%
device = ConnectHandler(device_type="cisco_ios", ip="172.16.0.10", username="ehsan", password="ehgh1363", secret="ehgh1363")

# %%
## store output of '?' command in xec mode (in  form of [command, command description]) into a list

device.enable()
counter_1 = 0
for no_layers in range(3):
    counter_1 += 1
    if counter_1 == 1:
        xec_cmd_layer_1 = []
        xec_cmd_layer_1 = device.send_command("?").split('\n')[2:-2] # remove first line and the last 2 lines (hostname)
        xec_cmd_desc_layer_1 = [" ".join(i.split()).split(" ", 1) 
                                                     for i in xec_cmd_layer_1]
    
    
    else:
        exec(f"xec_cmd_desc_layer_{str(counter_1)} = []") # dyamically create a list name for the respective layer 
        for cmd_desc_1 in vars()["xec_cmd_desc_layer_"+str(counter_1-1)]:
            counter_2 = 0
            if counter_1 == 2:
                help_cmd_output = device.send_command(cmd_desc_1[0]+" ?" "\x03").split('\n')
                try:
                    vars()["xec_cmd_desc_layer_"+str(counter_1)].append([[cmd_desc_1[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
                                                                  " ".join(j.split()).split(" ", 1)[1]] 
                                                                 for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])
                except IndexError:
                    pass
            
            elif counter_1 == 3:
                one_xec_cmd_desc = []
                for k in cmd_desc_1:            
                    counter_2 += 1
                    help_cmd_output = device.send_command(k[0]+" ?" "\x03").split('\n')
                    try:
                        one_xec_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
                                                                  " ".join(j.split()).split(" ", 1)[1]] 
                                                                 for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])
                    

                    except IndexError:
                        pass
                    if counter_2 == len(cmd_desc_1):
                        vars()["xec_cmd_desc_layer_"+str(counter_1)].append(one_xec_cmd_desc)

# %%
# # identify a numeric range at the end of the command (e.g. <100-200>), convert it to an integer before adding ?
# def genenrate_number_ip(command):
#     if command == 'A.B.C.D': # if it is an ip address
#         ip = "10.10.10.10"
#         return ip
#         pass
    
#     elif command == "<0-999999>.<0-999999>": # if it is an IOS version
#         version = "99.99"
#         return version
#         pass
    
#     elif re.match("<\d*-\d*>", command): # if it a numeric range
#         x = int(command.split(" ")[-1].split('-')[0][1:]) # extract the lower bound the range
#         y = int(command.split(" ")[-1].split('-')[1][:-1]) # extract the upper bound of the range
#         random_number = str(random.randint(x,y)) # generate a random number within the range
#         return random_number

# %%
# ## TEST

# device.enable()
# counter_1 = 0
# for no_layers in range(3):
#     counter_1 += 1
#     if counter_1 == 1:
#         conf_terminal_cmd_layer_1 = []
#         conf_terminal_cmd_layer_1 = device.send_config_set('?')[87:].split('\n')[2:-4] # start from inx 87, remove first line and the last 4 lines (hostname)
#         conf_terminal_cmd_desc_layer_1 = [" ".join(i.split()).split(" ", 1) 
#                                                      for i in conf_terminal_cmd_layer_1]
#     else:
#         exec(f"conf_terminal_cmd_desc_layer_{str(counter_1)} = []") # dyamically create a list name for the respective layer 
#         for cmd_desc_1 in vars()["conf_terminal_cmd_desc_layer_"+str( counter_1-1 )]:
#             counter_2 = 0
#             if counter_1 == 2:
#                 help_cmd_output = device.send_config_set( cmd_desc_1[0]+" ?" "\x03" )[87:].split('\n')[1:-4]
#                 try:
#                     conf_terminal_cmd_desc_layer_2.append([[cmd_desc_1[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                                   " ".join(j.split()).split(" ", 1)[1]] 
#                                                                  for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])
#                 except IndexError:
#                     pass
            
#             elif counter_1 == 3:
#                 one_conf_terminal_cmd_desc = []
                
#                 if len(cmd_desc_1) == 0: # if layer 2 command does not exist, append and empty list [] for the respective layer 3 index
#                     one_conf_terminal_cmd_desc.append([])
#                     vars()["conf_terminal_cmd_desc_layer_"+str(counter_1)].append([])
#                 else:
#                     for k in cmd_desc_1:
#                         counter_2 += 1
                        
#                         if k[0].split(" ")[-1] == "A.B.C.D" or re.match("<\d*-\d*>", k[0].split(" ")[-1]):
#                             try: # if it is a number range at the end of the command (e.g. <100-200>), convert it to an integer before adding ?
#     #                             print(k[0].split()[:-1][0] + " " + genenrate_number_ip(k[0].split()[-1]) + " ?")
#     #                             print(k[0])
#                                 help_cmd_output = device.send_config_set(k[0].split()[:-1][0] + " " + genenrate_number_ip(k[0].split()[-1]) + " ?" "\x03")[87:].split('\n')[1:-4]
#                                 one_conf_terminal_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                                               " ".join(j.split()).split(" ", 1)[1]] 
#                                                                              for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])

#         #                     except (ValueError, IndexError) as e:
#                             except TypeError: # if not a range:
#                                 pass
#                         else:
#                             try:
#                                 help_cmd_output = device.send_config_set(k[0]+" ?" "\x03")[87:].split('\n')[1:-4]
#                                 one_conf_terminal_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                                           " ".join(j.split()).split(" ", 1)[1]] 
#                                                                          for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])


#                             except IndexError:
#                                 pass
#                         if counter_2 == len(cmd_desc_1):
#                             vars()["conf_terminal_cmd_desc_layer_"+str(counter_1)].append(one_conf_terminal_cmd_desc)

# %%
conf_terminal_cmd_desc_layer_1[:5]
# Out:
# [['aaa', 'Authentication, Authorization and Accounting.'],
#  ['aal2-profile', 'Configure AAL2 profile'],
#  ['access-list', 'Add an access list entry'],
#  ['alarm-interface', 'Configure a specific Alarm Interface Card'],
#  ['alias', 'Create command alias']]

# %%
conf_terminal_cmd_desc_layer_2[:5]
# Out:
# [[['aaa new-model',
#    'Enable NEW access control commands and functions.(Disables OLD commands.)']],
#  [['aal2-profile custom', 'custom profiles']],
#  [['access-list <1-99>', 'IP standard access list'],
#   ['access-list <100-199>', 'IP extended access list'],
#   ['access-list <1000-1099>', 'IPX SAP access list'],
#   ['access-list <1100-1199>', 'Extended 48-bit MAC address access list'],
#   ['access-list <1200-1299>', 'IPX summary address access list'],
#   ['access-list <1300-1999>', 'IP standard access list (expanded range)'],
#   ['access-list <200-299>', 'Protocol type-code access list'],
#   ['access-list <2000-2699>', 'IP extended access list (expanded range)'],
#   ['access-list <300-399>', 'DECnet access list'],
#   ['access-list <600-699>', 'Appletalk access list'],
#   ['access-list <700-799>', '48-bit MAC address access list'],
#   ['access-list <800-899>', 'IPX standard access list'],
#   ['access-list <900-999>', 'IPX extended access list'],
#   ['access-list dynamic-extended', 'Extend the dynamic ACL absolute timer'],
#   ['access-list rate-limit', 'Simple rate-limit specific access list']],
#  [['alarm-interface <0-2>', 'Slot number']],
#  [['alias Buffer', 'config-owner-buffer'],
#   ['alias RITE-profile', 'Router IP traffic export profile command mode'],
#   ['alias RMI-Node-Config', 'Resource Policy Node Config mode'],
#   ['alias RMI-Resource-Group', 'Resource Group Config mode'],
#   ['alias RMI-Resource-Manager', 'Resource Manager Config mode'],
#   ['alias RMI-Resource-Policy', 'Resource Policy Config mode'],
#   ['alias SASL-profile', 'SASL profile configuration mode'],
#   ['alias aaa-attr-list', 'AAA attribute list config mode'],
#   ['alias aaa-user', 'AAA user definition'],
#   ['alias accept-dialin', 'VPDN group accept dialin configuration mode'],
#   ['alias accept-dialout', 'VPDN group accept dialout configuration mode'],
#   ['alias address-family', 'Address Family configuration mode'],
#   ['alias aic', 'Alarm Interface Card configuration mode'],
#   ['alias alps-ascu', 'ALPS ASCU configuration mode'],
#   ['alias alps-circuit', 'ALPS circuit configuration mode'],
#   ['alias appfw-application-aim', 'Appfw for AIM Configuration Mode'],
#   ['alias appfw-application-msnmsgr',
#    'Appfw for MSN Messenger Configuration Mode'],
#   ['alias appfw-application-ymsgr',
#    'Appfw for Yahoo! Messenger Configuration Mode'],
#   ['alias appfw-policy', 'Application FW Policy Configuration Mode'],
#   ['alias application-http', 'Appfw for HTTP Configuration Mode'],
#   ['alias archive', 'Archive the router configuration mode'],
#   ['alias auto-ip-sla-mpls', 'Auto IP SLA MPLS LSP Monitor configs'],
#   ['alias auto-ip-sla-mpls-lpd-params', 'Auto IP SLA MPLS LPD params configs'],
#   ['alias auto-ip-sla-mpls-params',
#    'Auto IP SLA MPLS LSP Monitor Params configs'],
#   ['alias bba-group', 'BBA Group configuration mode'],
#   ['alias boomerang', 'Boomerang configuration mode'],
#   ['alias call-filter-matchlist', 'Call Filter matchlist configuration mode'],
#   ['alias capf-server', 'Configure CAPF Server'],
#   ['alias casa-config', 'Casa configuration mode'],
#   ['alias cascustom', 'Cas custom configuration mode'],
#   ['alias cause-code-list', 'Voice Cause Code List configuration mode'],
#   ['alias cem', 'CESoIP configuration mode'],
#   ['alias ces-conn', 'CES connection configuration mode'],
#   ['alias ces-vc', 'CES VC configuration mode'],
#   ['alias cfg-pt-ruleset', 'Protocol Translation ruleset configuration mode'],
#   ['alias clid-group', 'CLID group configuration mode'],
#   ['alias cm-ac', 'AC-AC connect configuration mode'],
#   ['alias cm-fallback', 'cm-fallback configuration mode'],
#   ['alias cns-connect-config', 'CNS Connect Info Mode'],
#   ['alias cns-connect-intf-config', 'CNS Connect Intf Info Mode'],
#   ['alias cns-tmpl-connect-config', 'CNS Template Connect Info Mode'],
#   ['alias cns_inventory_submode', 'CNS Inventory SubMode'],
#   ['alias config-ip-sla-http-rr', 'IP SLAs HTTP raw request Configuration'],
#   ['alias config-l2tp-class', 'l2tp-class configuration mode'],
#   ['alias config-saa-http-rr', 'SAA HTTP raw request Configuration'],
#   ['alias config-tgrep', 'TRIP-Lite configuration mode'],
#   ['alias config-x25-huntgroup', 'X.25 hunt group configuration mode'],
#   ['alias config_app_global', 'Configure global settings'],
#   ['alias config_app_map', 'Configure application mapping'],
#   ['alias config_app_monitor', 'Configure application monitoring'],
#   ['alias config_app_session', 'Define script processes'],
#   ['alias config_voice', 'Define application services, modules, groups'],
#   ['alias config_voice_app', 'Define application parameters'],
#   ['alias configure', 'Global configuration mode'],
#   ['alias congestion', 'Frame Relay congestion configuration mode'],
#   ['alias control-plane', 'Control Plane configuration mode'],
#   ['alias control-plane-cef-exception-mode',
#    'Control Plane cef-exception configuration mode'],
#   ['alias control-plane-host-mode', 'Control Plane host configuration mode'],
#   ['alias control-plane-transit-mode',
#    'Control Plane transit configuration mode'],
#   ['alias controller', 'Controller configuration mode'],
#   ['alias cpf-classmap', 'Class-map configuration mode'],
#   ['alias cpf-policyclass', 'Class-in-Policy configuration mode'],
#   ['alias cpf-policymap', 'Policy-map configuration mode'],
#   ['alias cpu', 'config-owner-cpu'],
#   ['alias credentials', 'credentials configuration mode'],
#   ['alias crypto-ca-cert-chain', 'Crypto certificate entry mode'],
#   ['alias crypto-ca-cert-comm', 'Certificate query mode'],
#   ['alias crypto-ca-cert-map', 'Certificate map entry mode'],
#   ['alias crypto-ca-profile-enroll',
#    'Certificate enrollment profile entry mode'],
#   ['alias crypto-ca-root', 'Certificate authority trusted root entry mode'],
#   ['alias crypto-ca-trustpoint',
#    'Certificate authority trustpoint entry mode'],
#   ['alias crypto-cs-server', 'Certificate Server entry mode'],
#   ['alias crypto-ezvpn', 'Crypto ezvpn config mode'],
#   ['alias crypto-gdoi-group', 'Crypto GDOI group policy config mode'],
#   ['alias crypto-identity', 'Crypto identity config mode'],
#   ['alias crypto-ikmp', 'Crypto ISAKMP config mode'],
#   ['alias crypto-ikmp-browser-proxy',
#    'Crypto ISAKMP browser proxy config mode'],
#   ['alias crypto-ikmp-client-fw',
#    'Crypto ISAKMP client firewall policy config mode'],
#   ['alias crypto-ikmp-group', 'Crypto ISAKMP group policy config mode'],
#   ['alias crypto-ikmp-peer', 'Crypto ISAKMP peer policy configuration mode'],
#   ['alias crypto-ipsec-profile', 'IPSec policy profile mode'],
#   ['alias crypto-keyring', 'Crypto Keyring command mode'],
#   ['alias crypto-map', 'Crypto map config mode'],
#   ['alias crypto-pubkey', 'Crypto subsystem public key entry mode'],
#   ['alias crypto-transform', 'Crypto transform config mode'],
#   ['alias crypto-tti-petitioner', 'TTI Petitioner entry mode'],
#   ['alias crypto-tti-registrar', 'TTI Registrar entry mode'],
#   ['alias ctl-client', 'Configure CTL Client'],
#   ['alias dfp-submode', 'DFP config mode'],
#   ['alias dhcp', 'DHCP pool configuration mode'],
#   ['alias dhcp-class', 'DHCP class configuration mode'],
#   ['alias dhcp-pool-class', 'Per DHCP pool class configuration mode'],
#   ['alias dhcp-relay-info', 'DHCP class relay agent info configuration mode'],
#   ['alias dhcp-subnet-secondary',
#    'Per DHCP secondary subnet configuration mode'],
#   ['alias dnis-group', 'DNIS group configuration mode'],
#   ['alias dns-view', 'DNS View configuration mode'],
#   ['alias dns-view-list', 'DNS View-list configuration mode'],
#   ['alias dns-view-list-member', 'DNS View-list member configuration mode'],
#   ['alias dot1x-credential-mode',
#    'dot1x credential profile configuration mode'],
#   ['alias dspfarmprofile', 'DSPFARM Profile configuration mode'],
#   ['alias dynupd-http', 'Dynamic DNS update HTTP configuration mode'],
#   ['alias dynupd-method', 'Dynamic DNS update method configuration mode'],
#   ['alias emergency-response-location',
#    'voice emergency response location configuration mode'],
#   ['alias enum_rule', 'enum configuration mode'],
#   ['alias ephone', 'ephone configuration mode'],
#   ['alias ephone-dn', 'ephone-dn configuration mode'],
#   ['alias ephone-dn-template', 'ephone-dn-template configuration mode'],
#   ['alias ephone-hunt', 'ephone-hunt configuration mode'],
#   ['alias ephone-template', 'ephone-template configuration mode'],
#   ['alias exec', 'Exec mode'],
#   ['alias extcomm-list', 'IP Extended community-list configuration mode'],
#   ['alias fh_applet', 'FH Applet Entry Configuration'],
#   ['alias filterserver', 'AAA filter server definitions'],
#   ['alias flexdsprm-conn', 'Flex dsprm connection configuration mode'],
#   ['alias flow-cache', 'Flow aggregation cache config mode'],
#   ['alias flow-sampler-map', 'Flow sampler map config mode'],
#   ['alias flowexp', 'Flow Exporter configuration mode'],
#   ['alias flowmon', 'Flow Monitor configuration mode'],
#   ['alias flowrec', 'Flow Record configuration mode'],
#   ['alias fr-fr', 'FR/FR connection configuration mode'],
#   ['alias fr-pw', 'FR/PW connection configuration mode'],
#   ['alias fr-vcb-bmode', 'FR VC Bundle mode'],
#   ['alias fr-vcb-mmode', 'FR VC Bundle Member mode'],
#   ['alias frf5', 'FR/ATM Network IWF configuration mode'],
#   ['alias frf8', 'FR/ATM Service IWF configuration mode'],
#   ['alias funi-vc-config', 'FUNI virtual circuit configuration mode'],
#   ['alias gateway', 'Gateway configuration mode'],
#   ['alias gdoi-coop-ks-config', 'Crypto GDOI server redundancy config mode'],
#   ['alias gdoi-local-server', 'Crypto GDOI local server policy config mode'],
#   ['alias gdoi-sa-ipsec',
#    'Crypto GDOI local server IPsec SA policy config mode'],
#   ['alias gw', 'Webvpn virtual gateway configuration'],
#   ['alias gw-accounting-aaa', 'Gateway accounting aaa configuration mode'],
#   ['alias hms-consumer', 'HMS Controller configuration mode'],
#   ['alias hms-controller', 'HMS Controller configuration mode'],
#   ['alias hostlist', 'Host list configuration mode'],
#   ['alias hunt-group', 'voice hunt-group configuration mode'],
#   ['alias identity-policy-mode', 'identity policy configuration mode'],
#   ['alias identity-profile-mode', 'identity profile configuration mode'],
#   ['alias interface', 'Interface configuration mode'],
#   ['alias interface-dlci', 'Frame Relay dlci configuration mode'],
#   ['alias interface-range', 'Interface range configuration mode'],
#   ['alias ip-explicit-path', 'IP explicit path configuration mode'],
#   ['alias ip-sla', 'IP SLAs entry configuration'],
#   ['alias ip-sla-dhcp', 'IP SLAs dhcp configuration'],
#   ['alias ip-sla-dlsw', 'IP SLAs dlsw configuration'],
#   ['alias ip-sla-dns', 'IP SLAs dns configuration'],
#   ['alias ip-sla-echo', 'IP SLAs echo configuration'],
#   ['alias ip-sla-frameRelay', 'IP SLAs FrameRelay configuration'],
#   ['alias ip-sla-ftp', 'IP SLAs ftp configuration'],
#   ['alias ip-sla-http', 'IP SLAs http configuration'],
#   ['alias ip-sla-icmpjitter', 'IP SLAs icmpjitter configuration'],
#   ['alias ip-sla-jitter', 'IP SLAs jitter configuration'],
#   ['alias ip-sla-pathEcho', 'IP SLAs pathEcho configuration'],
#   ['alias ip-sla-pathJitter', 'IP SLAs pathJitter configuration'],
#   ['alias ip-sla-tcpConnect', 'IP SLAs tcpConnect configuration'],
#   ['alias ip-sla-udpEcho', 'IP SLAs udpEcho configuration'],
#   ['alias ip-sla-voip', 'IP SLA voip configuration'],
#   ['alias ip-sla-voip-rtp', 'IP SLAs rtp configuration'],
#   ['alias ip-vrf', 'Configure IP VRF parameters'],
#   ['alias ipc-zone-assoc-protocol-sctp', 'ipc protocol sctp mode'],
#   ['alias ipczone', 'IPC Zone config mode'],
#   ['alias ipczone-assoc', 'IPC Association config mode'],
#   ['alias ipenacl', 'IP named extended access-list configuration mode'],
#   ['alias ipnat-pool', 'IP NAT pool configuration mode'],
#   ['alias ipnat-portmap', 'IP NAT portmap configuration mode'],
#   ['alias ipnat-sbc', 'IP NAT SIP-SBC config mode'],
#   ['alias ipnat-sbc-vrf', 'IP NAT SIP-SBC vrf config mode'],
#   ['alias ipnat-snat', 'IP SNAT configuration mode'],
#   ['alias ipnat-snat-backup', 'IP SNAT Backup configuration mode'],
#   ['alias ipnat-snat-primary', 'IP SNAT Primary configuration mode'],
#   ['alias ipnat-snat-redundancy', 'IP SNAT Redundancy configuration mode'],
#   ['alias ips-seap-rules', 'IPS event action rules configuration mode'],
#   ['alias ips-sigdef-sig', 'IPS signature number name configuration mode'],
#   ['alias ipscataction', 'IPS Category name configuration mode'],
#   ['alias ipsnacl', 'IP named simple access-list configuration mode'],
#   ['alias ipssigau', 'IPS Auto Update configuration mode'],
#   ['alias ipssigcat', 'IPS signature category configuration mode'],
#   ['alias ipssigdef-action', 'IPS Signature actions configuration mode'],
#   ['alias ipssigdef-engine', 'IPS signature def Engine configuration mode'],
#   ['alias ipssigdef-status', 'IPS signature def Status mode'],
#   ['alias ipv6-router', 'IPv6 router configuration mode'],
#   ['alias ipv6acl', 'IPv6 access-list configuration mode'],
#   ['alias ipv6dhcp', 'IPv6 DHCP configuration mode'],
#   ['alias ipx-router', 'IPX router configuration mode'],
#   ['alias ipxenacl', 'IPX named extended access-list configuration mode'],
#   ['alias ipxsapnacl', 'IPX named SAP access-list configuration mode'],
#   ['alias ipxsnacl', 'IPX named standard access-list configuration mode'],
#   ['alias ipxsumnacl', 'IPX named Summary access-list configuration mode'],
#   ['alias irec-agent', 'irec agent configuration mode'],
#   ['alias isakmp-profile', 'Crypto ISAKMP profile command mode'],
#   ['alias key-chain', 'Key-chain configuration mode'],
#   ['alias key-chain-key', 'Key-chain key configuration mode'],
#   ['alias kron-occurrence', 'Kron Occurrence SubMode'],
#   ['alias kron-policy', 'Kron Policy SubMode'],
#   ['alias l2', 'vfi configuration mode'],
#   ['alias lane', 'ATM Lan Emulation Lecs Configuration Table'],
#   ['alias line', 'Line configuration mode'],
#   ['alias log_config', 'Log configuration changes made via the CLI'],
#   ['alias lw-vlan-id', 'VLAN-id configuration mode'],
#   ['alias lw-vlan-range', 'VLAN-range configuration mode'],
#   ['alias map-class', 'Map class configuration mode'],
#   ['alias map-list', 'Map list configuration mode'],
#   ['alias memory', 'config-owner-memory'],
#   ['alias mgcpprofile', 'MGCP Profile configuration mode'],
#   ['alias mipv6-config-ha', 'Mobile IPv6 HA mode'],
#   ['alias mipv6-config-ha-host', 'Mobile IPv6 Home Agent Host config mode'],
#   ['alias mobile-networks', 'Mobile Networks mode'],
#   ['alias mobile-router', 'Mobile Router mode'],
#   ['alias mpls_atm_vc', 'ATM MPLS Control VC Sub-commands'],
#   ['alias mpoa-client', 'MPOA Client'],
#   ['alias mpoa-server', 'MPOA Server'],
#   ['alias mrm-manager', 'IP Multicast Routing Monitor config mode'],
#   ['alias null-interface', 'Null interface configuration mode'],
#   ['alias oam', 'LSP Verification configuration mode'],
#   ['alias oer_br', 'OER border router configuration submode'],
#   ['alias oer_mc', 'OER master controller configuration submode'],
#   ['alias oer_mc_api_provider', 'OER MC API Provider configuration submode'],
#   ['alias oer_mc_br', 'OER managed border router configuration submode'],
#   ['alias oer_mc_br_if', 'OER Border Exit configuration submode'],
#   ['alias oer_mc_learn',
#    'OER Top Talker and Delay learning configuration submode'],
#   ['alias oer_mc_learn_list', 'OER learn list configuration submode'],
#   ['alias oer_mc_map', 'oer-map config mode'],
#   ['alias parameter_map_cfg', 'parameter-map configuration mode'],
#   ['alias policy-list', 'IP Policy List configuration mode'],
#   ['alias preauth', 'AAA Preauth definitions'],
#   ['alias presence', 'presence configuration mode'],
#   ['alias profile', 'Subscriber profile configuration mode'],
#   ['alias pseudowire-class', 'Pseudowire-class configuration mode'],
#   ['alias public-key-chain', 'Crypto public key identification mode'],
#   ['alias public-key-chain-key', 'Crypto public key entry mode'],
#   ['alias public-key-chain-key-ring', 'Crypto public key entry mode'],
#   ['alias qosclassmap', 'QoS Class Map configuration mode'],
#   ['alias qosclasspolice', 'QoS Class Police configuration mode'],
#   ['alias qospolicymap', 'QoS Policy Map configuration mode'],
#   ['alias qospolicymapclass', 'QoS Policy Map class configuration mode'],
#   ['alias radius-attrl', 'Radius Attribute-List Definition'],
#   ['alias radius-locsvr', 'Radius Application configuration'],
#   ['alias radsrv', 'Local RADIUS server configuration mode'],
#   ['alias radsrvgrp', 'User group configuration mode'],
#   ['alias red-group', 'random-detect group configuration mode'],
#   ['alias redundancy', 'redundancy config mode'],
#   ['alias regex-translation-rule', 'voip translation-rule configuration mode'],
#   ['alias request-dialin', 'VPDN group request dialin configuration mode'],
#   ['alias request-dialout', 'VPDN group request dialout configuration mode'],
#   ['alias rf-mode-interdev-local', 'ipc sctp local config mode'],
#   ['alias rf-mode-interdev-remote', 'ipc sctp remote config mode'],
#   ['alias rf-mode-interdevice', 'redundancy config mode'],
#   ['alias rlm-group', 'RLM Group configuration mode'],
#   ['alias rlm-group-sc', 'RLM server/client link configuration mode'],
#   ['alias roles', 'Role configuration mode'],
#   ['alias route-map', 'Route map config mode'],
#   ['alias router', 'Router configuration mode'],
#   ['alias rsvp-local-if-policy',
#    'RSVP local policy interface configuration mode'],
#   ['alias rsvp-local-policy', 'RSVP local policy configuration mode'],
#   ['alias rsvp-local-subif-policy',
#    'RSVP local policy sub-interface configuration mode'],
#   ['alias saa', 'SAA entry configuration'],
#   ['alias saa-dhcp', 'SAA dhcp configuration'],
#   ['alias saa-dlsw', 'SAA dlsw configuration'],
#   ['alias saa-dns', 'SAA dns configuration'],
#   ['alias saa-echo', 'SAA echo configuration'],
#   ['alias saa-frameRelay', 'SAA frameRelay configuration'],
#   ['alias saa-ftp', 'SAA ftp configuration'],
#   ['alias saa-http', 'SAA http configuration'],
#   ['alias saa-jitter', 'SAA jitter configuration'],
#   ['alias saa-pathEcho', 'SAA pathEcho configuration'],
#   ['alias saa-pathJitter', 'SAA pathJitter configuration'],
#   ['alias saa-slm-ctrlr-if', 'SAA slm controller/interface configuration'],
#   ['alias saa-slmAtm', 'SAA slm ATM configuration'],
#   ['alias saa-slmFrIf', 'SAA slm FrameRelay Interface configuration'],
#   ['alias saa-tcpConnect', 'SAA tcpConnect configuration'],
#   ['alias saa-udpEcho', 'SAA udpEcho configuration'],
#   ['alias saa-voip', 'SAA VoIP configuration'],
#   ['alias sampler', 'Sampler configuration mode'],
#   ['alias sat_init_config', 'Satellite module initial configuration'],
#   ['alias sccpccmgroup', 'SCCP CCM group configuration mode'],
#   ['alias sccpplar', 'SCCP PLAR configuration mode'],
#   ['alias sctp-export', 'SCTP export configuration commands'],
#   ['alias seczonecfg', 'Security Zone Configuration Mode'],
#   ['alias seczonepaircfg', 'Security Zone Pair Configuration Mode'],
#   ['alias serviceflow', 'Service Flow configuration mode'],
#   ['alias settlement_tag', 'Settlement configuration mode'],
#   ['alias sg-radius', 'Radius Server-group Definition'],
#   ['alias sg-tacacs+', 'Tacacs+ Server-group Definition'],
#   ['alias signaling-class', 'Signaling class configuration mode'],
#   ['alias sip-ua', 'SIP UA configuration mode'],
#   ['alias sla-monitor-lspPing', 'IP SLAs lsp ping configuration'],
#   ['alias sla-monitor-lspTrace', 'IP SLA Monitor lsp trace configuration'],
#   ['alias sla-slm', 'IP SLAs Slm configuration'],
#   ['alias sla-slm-ctrlr-if', 'IP SLAs slm controller/interface configuration'],
#   ['alias sla-slmAtm', 'IP SLAs SlmAtm configuration'],
#   ['alias sla-slmFrIf', 'IP SLAs SlmFrameRelay Interface configuration'],
#   ['alias sla-slmfr', 'IP SLAs FR SLM configuration'],
#   ['alias source-group', 'Voice Source Group configuration mode'],
#   ['alias srst-video', 'cm-fallback video configuration mode'],
#   ['alias stcappfac', 'STCAPP feature access-code configuration mode'],
#   ['alias stcappfsd', 'STCAPP feature speed-dial configuration mode'],
#   ['alias subinterface', 'Subinterface configuration mode'],
#   ['alias tablemap', 'Table Map configuration mode'],
#   ['alias tdm-conn', 'TDM connection configuration mode'],
#   ['alias telephony-service', 'telephony-service configuration mode'],
#   ['alias telephony-service-video',
#    'Telephony service video configuration mode'],
#   ['alias template', 'Template configuration mode'],
#   ['alias template', 'peer-policy peer-policy configuration mode'],
#   ['alias template', 'peer-session peer-session configuration mode'],
#   ['alias tidp-group', 'TIDP Group configuration mode'],
#   ['alias tidp-keyset', 'TIDP key-set configuration mode'],
#   ['alias tms-consumer', 'TMS Consumer configuration mode'],
#   ['alias tms-controller', 'TMS Controller configuration mode'],
#   ['alias top-talkers', 'Netflow top talkers config mode'],
#   ['alias tracking-config', 'Tracking configuration mode'],
#   ['alias trange', 'time-range configuration mode'],
#   ['alias translation-profile',
#    'Voice Translation Profile configuration mode'],
#   ['alias translation-rule', 'Translation Rule configuration mode'],
#   ['alias trunk-group', 'Trunk group configuration mode'],
#   ['alias vc-class', 'VC class configuration mode'],
#   ['alias vc-group', 'VC group configuration mode'],
#   ['alias view', 'View configuration mode'],
#   ['alias vm-integration', 'voicemail integration configuration mode'],
#   ['alias voice-cause-code', 'Voice Cause Code configuration mode'],
#   ['alias voice-register-dialplan',
#    'voice-register-dialplan configuration mode'],
#   ['alias voice-register-dn', 'voice-register-dn configuration mode'],
#   ['alias voice-register-global', 'voice-register-global configuration mode'],
#   ['alias voice-register-pool', 'voice-register-pool configuration mode'],
#   ['alias voice-register-temp', 'voice-register-temp configuration mode'],
#   ['alias voice-service', 'Voice service configuration mode'],
#   ['alias voice-service-h323', 'Voice service h323 configuration mode'],
#   ['alias voice-service-session', 'Voice service session configuration mode'],
#   ['alias voice-service-sip', 'Voice service sip configuration mode'],
#   ['alias voice-uri-class', 'Voice URI Class configuration mode'],
#   ['alias voicecard', 'Voice card configuration mode'],
#   ['alias voicecl-cptone', 'Voice Class CPTone configuration mode'],
#   ['alias voicecl-cptone-dt', 'CPtone dualtone configuration mode'],
#   ['alias voicecl-dt-detect',
#    'Voice Class Dualtone Detect configuration mode'],
#   ['alias voiceclass', 'Voice Class configuration mode'],
#   ['alias voicednismaps', 'Dnis Map Configuration'],
#   ['alias voiceport', 'Voice configuration mode'],
#   ['alias voipdialpeer', 'Dial Peer configuration mode'],
#   ['alias voipdpcor', 'Dial Peer Class of Restriction configuration mode'],
#   ['alias voipdpcorlist',
#    'Dial Peer Class of Restriction List configuration mode'],
#   ['alias vpdn-group', 'VPDN group configuration mode'],
#   ['alias vpdn-template', 'VPDN template configuration mode'],
#   ['alias webvpn', 'Webvpn virtual context configuration'],
#   ['alias webvpn-acl', 'Webvpn ACL configuration'],
#   ['alias webvpn-cifs-url', 'Webvpn CIFS URL list configuration'],
#   ['alias webvpn-group-policy', 'Webvpn group policy configuration'],
#   ['alias webvpn-nbnslist', 'Webvpn VW ctxt NBNS list configuration'],
#   ['alias webvpn-port-fwd', 'Webvpn port-forward list configuration'],
#   ['alias webvpn-sso-server', 'SSO Server configuration'],
#   ['alias webvpn-time-range', 'Webvpn time range configuration'],
#   ['alias webvpn-url', 'Webvpn URL list configuration'],
#   ['alias x25-profile', 'X.25 profile configuration mode'],
#   ['alias xconnect-cem-config', 'Xconnect cem configuration submode'],
#   ['alias xconnect-conn-config', 'Xconnect connect configuration submode'],
#   ['alias xconnect-dlci-config', 'Xconnect FR DLCI configuration submode'],
#   ['alias xconnect-if-config', 'Xconnect interface configuration submode'],
#   ['alias xconnect-pvc-config',
#    'Xconnect atm l2transport PVC configuration submode'],
#   ['alias xconnect-pvp-config',
#    'Xconnect atm l2transport PVP configuration submode'],
#   ['alias xconnect-subif-config',
#    'Xconnect sub-interface configuration submode'],
#   ['alias xml-app', 'XML Application configuration mode'],
#   ['alias xml-transport', 'XML Transport configuration mode']]]

# %%
conf_terminal_cmd_desc_layer_3[:5]
# Out:
# [[[]],
#  [[['aal2-profile custom <1-255>', 'Enter the Profile number']]],
#  [[['access-list <1-99> deny', 'Specify packets to reject'],
#    ['access-list <1-99> permit', 'Specify packets to forward'],
#    ['access-list <1-99> remark', 'Access list entry comment']],
#   [['access-list <100-199> deny', 'Specify packets to reject'],
#    ['access-list <100-199> dynamic',
#     'Specify a DYNAMIC list of PERMITs or DENYs'],
#    ['access-list <100-199> permit', 'Specify packets to forward'],
#    ['access-list <100-199> remark', 'Access list entry comment']],
#   [['access-list <1000-1099> deny', 'Specify packets to reject'],
#    ['access-list <1000-1099> permit', 'Specify packets to forward']],
#   [['access-list <1100-1199> deny', 'Specify packets to reject'],
#    ['access-list <1100-1199> permit', 'Specify packets to forward']],
#   [['access-list <1200-1299> deny', 'Specify addresses to reject'],
#    ['access-list <1200-1299> permit', 'Specify addresses to permit']],
#   [['access-list <1300-1999> deny', 'Specify packets to reject'],
#    ['access-list <1300-1999> permit', 'Specify packets to forward'],
#    ['access-list <1300-1999> remark', 'Access list entry comment']],
#   [['access-list <200-299> deny', 'Specify packets to reject'],
#    ['access-list <200-299> permit', 'Specify packets to forward']],
#   [['access-list <2000-2699> deny', 'Specify packets to reject'],
#    ['access-list <2000-2699> dynamic',
#     'Specify a DYNAMIC list of PERMITs or DENYs'],
#    ['access-list <2000-2699> permit', 'Specify packets to forward'],
#    ['access-list <2000-2699> remark', 'Access list entry comment']],
#   [['access-list <300-399> deny', 'Specify packets to reject'],
#    ['access-list <300-399> permit', 'Specify packets to forward']],
#   [['access-list <600-699> deny', 'Specify packets to reject'],
#    ['access-list <600-699> permit', 'Specify packets to forward']],
#   [['access-list <700-799> deny', 'Specify packets to reject'],
#    ['access-list <700-799> permit', 'Specify packets to forward']],
#   [['access-list <800-899> deny', 'Specify packets to reject'],
#    ['access-list <800-899> permit', 'Specify packets to permit']],
#   [['access-list <900-999> deny', 'Specify packets to reject'],
#    ['access-list <900-999> permit', 'Specify packets to permit']],
#   [],
#   [['access-list rate-limit <0-99>', 'Precedence ACL index'],
#    ['access-list rate-limit <100-199>', 'MAC address ACL index'],
#    ['access-list rate-limit <200-299>', 'mpls exp ACL index']]],
#  [[]],
#  [[['alias Buffer WORD', 'Alias name']],
#   [['alias RITE-profile WORD', 'Alias name']],
#   [['alias RMI-Node-Config WORD', 'Alias name']],
#   [['alias RMI-Resource-Group WORD', 'Alias name']],
#   [['alias RMI-Resource-Manager WORD', 'Alias name']],
#   [['alias RMI-Resource-Policy WORD', 'Alias name']],
#   [['alias SASL-profile WORD', 'Alias name']],
#   [['alias aaa-attr-list WORD', 'Alias name']],
#   [['alias aaa-user WORD', 'Alias name']],
#   [['alias accept-dialin WORD', 'Alias name']],
#   [['alias accept-dialout WORD', 'Alias name']],
#   [['alias address-family WORD', 'Alias name']],
#   [['alias aic WORD', 'Alias name']],
#   [['alias alps-ascu WORD', 'Alias name']],
#   [['alias alps-circuit WORD', 'Alias name']],
#   [['alias appfw-application-aim WORD', 'Alias name']],
#   [['alias appfw-application-msnmsgr WORD', 'Alias name']],
#   [['alias appfw-application-ymsgr WORD', 'Alias name']],
#   [['alias appfw-policy WORD', 'Alias name']],
#   [['alias application-http WORD', 'Alias name']],
#   [['alias archive WORD', 'Alias name']],
#   [['alias auto-ip-sla-mpls WORD', 'Alias name']],
#   [['alias auto-ip-sla-mpls-lpd-params WORD', 'Alias name']],
#   [['alias auto-ip-sla-mpls-params WORD', 'Alias name']],
#   [['alias bba-group WORD', 'Alias name']],
#   [['alias boomerang WORD', 'Alias name']],
#   [['alias call-filter-matchlist WORD', 'Alias name']],
#   [['alias capf-server WORD', 'Alias name']],
#   [['alias casa-config WORD', 'Alias name']],
#   [['alias cascustom WORD', 'Alias name']],
#   [['alias cause-code-list WORD', 'Alias name']],
#   [['alias cem WORD', 'Alias name']],
#   [['alias ces-conn WORD', 'Alias name']],
#   [['alias ces-vc WORD', 'Alias name']],
#   [['alias cfg-pt-ruleset WORD', 'Alias name']],
#   [['alias clid-group WORD', 'Alias name']],
#   [['alias cm-ac WORD', 'Alias name']],
#   [['alias cm-fallback WORD', 'Alias name']],
#   [['alias cns-connect-config WORD', 'Alias name']],
#   [['alias cns-connect-intf-config WORD', 'Alias name']],
#   [['alias cns-tmpl-connect-config WORD', 'Alias name']],
#   [['alias cns_inventory_submode WORD', 'Alias name']],
#   [['alias config-ip-sla-http-rr WORD', 'Alias name']],
#   [['alias config-l2tp-class WORD', 'Alias name']],
#   [['alias config-saa-http-rr WORD', 'Alias name']],
#   [['alias config-tgrep WORD', 'Alias name']],
#   [['alias config-x25-huntgroup WORD', 'Alias name']],
#   [['alias config_app_global WORD', 'Alias name']],
#   [['alias config_app_map WORD', 'Alias name']],
#   [['alias config_app_monitor WORD', 'Alias name']],
#   [['alias config_app_session WORD', 'Alias name']],
#   [['alias config_voice WORD', 'Alias name']],
#   [['alias config_voice_app WORD', 'Alias name']],
#   [['alias configure WORD', 'Alias name']],
#   [['alias congestion WORD', 'Alias name']],
#   [['alias control-plane WORD', 'Alias name']],
#   [['alias control-plane-cef-exception-mode WORD', 'Alias name']],
#   [['alias control-plane-host-mode WORD', 'Alias name']],
#   [['alias control-plane-transit-mode WORD', 'Alias name']],
#   [['alias controller WORD', 'Alias name']],
#   [['alias cpf-classmap WORD', 'Alias name']],
#   [['alias cpf-policyclass WORD', 'Alias name']],
#   [['alias cpf-policymap WORD', 'Alias name']],
#   [['alias cpu WORD', 'Alias name']],
#   [['alias credentials WORD', 'Alias name']],
#   [['alias crypto-ca-cert-chain WORD', 'Alias name']],
#   [['alias crypto-ca-cert-comm WORD', 'Alias name']],
#   [['alias crypto-ca-cert-map WORD', 'Alias name']],
#   [['alias crypto-ca-profile-enroll WORD', 'Alias name']],
#   [['alias crypto-ca-root WORD', 'Alias name']],
#   [['alias crypto-ca-trustpoint WORD', 'Alias name']],
#   [['alias crypto-cs-server WORD', 'Alias name']],
#   [['alias crypto-ezvpn WORD', 'Alias name']],
#   [['alias crypto-gdoi-group WORD', 'Alias name']],
#   [['alias crypto-identity WORD', 'Alias name']],
#   [['alias crypto-ikmp WORD', 'Alias name']],
#   [['alias crypto-ikmp-browser-proxy WORD', 'Alias name']],
#   [['alias crypto-ikmp-client-fw WORD', 'Alias name']],
#   [['alias crypto-ikmp-group WORD', 'Alias name']],
#   [['alias crypto-ikmp-peer WORD', 'Alias name']],
#   [['alias crypto-ipsec-profile WORD', 'Alias name']],
#   [['alias crypto-keyring WORD', 'Alias name']],
#   [['alias crypto-map WORD', 'Alias name']],
#   [['alias crypto-pubkey WORD', 'Alias name']],
#   [['alias crypto-transform WORD', 'Alias name']],
#   [['alias crypto-tti-petitioner WORD', 'Alias name']],
#   [['alias crypto-tti-registrar WORD', 'Alias name']],
#   [['alias ctl-client WORD', 'Alias name']],
#   [['alias dfp-submode WORD', 'Alias name']],
#   [['alias dhcp WORD', 'Alias name']],
#   [['alias dhcp-class WORD', 'Alias name']],
#   [['alias dhcp-pool-class WORD', 'Alias name']],
#   [['alias dhcp-relay-info WORD', 'Alias name']],
#   [['alias dhcp-subnet-secondary WORD', 'Alias name']],
#   [['alias dnis-group WORD', 'Alias name']],
#   [['alias dns-view WORD', 'Alias name']],
#   [['alias dns-view-list WORD', 'Alias name']],
#   [['alias dns-view-list-member WORD', 'Alias name']],
#   [['alias dot1x-credential-mode WORD', 'Alias name']],
#   [['alias dspfarmprofile WORD', 'Alias name']],
#   [['alias dynupd-http WORD', 'Alias name']],
#   [['alias dynupd-method WORD', 'Alias name']],
#   [['alias emergency-response-location WORD', 'Alias name']],
#   [['alias enum_rule WORD', 'Alias name']],
#   [['alias ephone WORD', 'Alias name']],
#   [['alias ephone-dn WORD', 'Alias name']],
#   [['alias ephone-dn-template WORD', 'Alias name']],
#   [['alias ephone-hunt WORD', 'Alias name']],
#   [['alias ephone-template WORD', 'Alias name']],
#   [['alias exec WORD', 'Alias name']],
#   [['alias extcomm-list WORD', 'Alias name']],
#   [['alias fh_applet WORD', 'Alias name']],
#   [['alias filterserver WORD', 'Alias name']],
#   [['alias flexdsprm-conn WORD', 'Alias name']],
#   [['alias flow-cache WORD', 'Alias name']],
#   [['alias flow-sampler-map WORD', 'Alias name']],
#   [['alias flowexp WORD', 'Alias name']],
#   [['alias flowmon WORD', 'Alias name']],
#   [['alias flowrec WORD', 'Alias name']],
#   [['alias fr-fr WORD', 'Alias name']],
#   [['alias fr-pw WORD', 'Alias name']],
#   [['alias fr-vcb-bmode WORD', 'Alias name']],
#   [['alias fr-vcb-mmode WORD', 'Alias name']],
#   [['alias frf5 WORD', 'Alias name']],
#   [['alias frf8 WORD', 'Alias name']],
#   [['alias funi-vc-config WORD', 'Alias name']],
#   [['alias gateway WORD', 'Alias name']],
#   [['alias gdoi-coop-ks-config WORD', 'Alias name']],
#   [['alias gdoi-local-server WORD', 'Alias name']],
#   [['alias gdoi-sa-ipsec WORD', 'Alias name']],
#   [['alias gw WORD', 'Alias name']],
#   [['alias gw-accounting-aaa WORD', 'Alias name']],
#   [['alias hms-consumer WORD', 'Alias name']],
#   [['alias hms-controller WORD', 'Alias name']],
#   [['alias hostlist WORD', 'Alias name']],
#   [['alias hunt-group WORD', 'Alias name']],
#   [['alias identity-policy-mode WORD', 'Alias name']],
#   [['alias identity-profile-mode WORD', 'Alias name']],
#   [['alias interface WORD', 'Alias name']],
#   [['alias interface-dlci WORD', 'Alias name']],
#   [['alias interface-range WORD', 'Alias name']],
#   [['alias ip-explicit-path WORD', 'Alias name']],
#   [['alias ip-sla WORD', 'Alias name']],
#   [['alias ip-sla-dhcp WORD', 'Alias name']],
#   [['alias ip-sla-dlsw WORD', 'Alias name']],
#   [['alias ip-sla-dns WORD', 'Alias name']],
#   [['alias ip-sla-echo WORD', 'Alias name']],
#   [['alias ip-sla-frameRelay WORD', 'Alias name']],
#   [['alias ip-sla-ftp WORD', 'Alias name']],
#   [['alias ip-sla-http WORD', 'Alias name']],
#   [['alias ip-sla-icmpjitter WORD', 'Alias name']],
#   [['alias ip-sla-jitter WORD', 'Alias name']],
#   [['alias ip-sla-pathEcho WORD', 'Alias name']],
#   [['alias ip-sla-pathJitter WORD', 'Alias name']],
#   [['alias ip-sla-tcpConnect WORD', 'Alias name']],
#   [['alias ip-sla-udpEcho WORD', 'Alias name']],
#   [['alias ip-sla-voip WORD', 'Alias name']],
#   [['alias ip-sla-voip-rtp WORD', 'Alias name']],
#   [['alias ip-vrf WORD', 'Alias name']],
#   [['alias ipc-zone-assoc-protocol-sctp WORD', 'Alias name']],
#   [['alias ipczone WORD', 'Alias name']],
#   [['alias ipczone-assoc WORD', 'Alias name']],
#   [['alias ipenacl WORD', 'Alias name']],
#   [['alias ipnat-pool WORD', 'Alias name']],
#   [['alias ipnat-portmap WORD', 'Alias name']],
#   [['alias ipnat-sbc WORD', 'Alias name']],
#   [['alias ipnat-sbc-vrf WORD', 'Alias name']],
#   [['alias ipnat-snat WORD', 'Alias name']],
#   [['alias ipnat-snat-backup WORD', 'Alias name']],
#   [['alias ipnat-snat-primary WORD', 'Alias name']],
#   [['alias ipnat-snat-redundancy WORD', 'Alias name']],
#   [['alias ips-seap-rules WORD', 'Alias name']],
#   [['alias ips-sigdef-sig WORD', 'Alias name']],
#   [['alias ipscataction WORD', 'Alias name']],
#   [['alias ipsnacl WORD', 'Alias name']],
#   [['alias ipssigau WORD', 'Alias name']],
#   [['alias ipssigcat WORD', 'Alias name']],
#   [['alias ipssigdef-action WORD', 'Alias name']],
#   [['alias ipssigdef-engine WORD', 'Alias name']],
#   [['alias ipssigdef-status WORD', 'Alias name']],
#   [['alias ipv6-router WORD', 'Alias name']],
#   [['alias ipv6acl WORD', 'Alias name']],
#   [['alias ipv6dhcp WORD', 'Alias name']],
#   [['alias ipx-router WORD', 'Alias name']],
#   [['alias ipxenacl WORD', 'Alias name']],
#   [['alias ipxsapnacl WORD', 'Alias name']],
#   [['alias ipxsnacl WORD', 'Alias name']],
#   [['alias ipxsumnacl WORD', 'Alias name']],
#   [['alias irec-agent WORD', 'Alias name']],
#   [['alias isakmp-profile WORD', 'Alias name']],
#   [['alias key-chain WORD', 'Alias name']],
#   [['alias key-chain-key WORD', 'Alias name']],
#   [['alias kron-occurrence WORD', 'Alias name']],
#   [['alias kron-policy WORD', 'Alias name']],
#   [['alias l2 WORD', 'Alias name']],
#   [['alias lane WORD', 'Alias name']],
#   [['alias line WORD', 'Alias name']],
#   [['alias log_config WORD', 'Alias name']],
#   [['alias lw-vlan-id WORD', 'Alias name']],
#   [['alias lw-vlan-range WORD', 'Alias name']],
#   [['alias map-class WORD', 'Alias name']],
#   [['alias map-list WORD', 'Alias name']],
#   [['alias memory WORD', 'Alias name']],
#   [['alias mgcpprofile WORD', 'Alias name']],
#   [['alias mipv6-config-ha WORD', 'Alias name']],
#   [['alias mipv6-config-ha-host WORD', 'Alias name']],
#   [['alias mobile-networks WORD', 'Alias name']],
#   [['alias mobile-router WORD', 'Alias name']],
#   [['alias mpls_atm_vc WORD', 'Alias name']],
#   [['alias mpoa-client WORD', 'Alias name']],
#   [['alias mpoa-server WORD', 'Alias name']],
#   [['alias mrm-manager WORD', 'Alias name']],
#   [['alias null-interface WORD', 'Alias name']],
#   [['alias oam WORD', 'Alias name']],
#   [['alias oer_br WORD', 'Alias name']],
#   [['alias oer_mc WORD', 'Alias name']],
#   [['alias oer_mc_api_provider WORD', 'Alias name']],
#   [['alias oer_mc_br WORD', 'Alias name']],
#   [['alias oer_mc_br_if WORD', 'Alias name']],
#   [['alias oer_mc_learn WORD', 'Alias name']],
#   [['alias oer_mc_learn_list WORD', 'Alias name']],
#   [['alias oer_mc_map WORD', 'Alias name']],
#   [['alias parameter_map_cfg WORD', 'Alias name']],
#   [['alias policy-list WORD', 'Alias name']],
#   [['alias preauth WORD', 'Alias name']],
#   [['alias presence WORD', 'Alias name']],
#   [['alias profile WORD', 'Alias name']],
#   [['alias pseudowire-class WORD', 'Alias name']],
#   [['alias public-key-chain WORD', 'Alias name']],
#   [['alias public-key-chain-key WORD', 'Alias name']],
#   [['alias public-key-chain-key-ring WORD', 'Alias name']],
#   [['alias qosclassmap WORD', 'Alias name']],
#   [['alias qosclasspolice WORD', 'Alias name']],
#   [['alias qospolicymap WORD', 'Alias name']],
#   [['alias qospolicymapclass WORD', 'Alias name']],
#   [['alias radius-attrl WORD', 'Alias name']],
#   [['alias radius-locsvr WORD', 'Alias name']],
#   [['alias radsrv WORD', 'Alias name']],
#   [['alias radsrvgrp WORD', 'Alias name']],
#   [['alias red-group WORD', 'Alias name']],
#   [['alias redundancy WORD', 'Alias name']],
#   [['alias regex-translation-rule WORD', 'Alias name']],
#   [['alias request-dialin WORD', 'Alias name']],
#   [['alias request-dialout WORD', 'Alias name']],
#   [['alias rf-mode-interdev-local WORD', 'Alias name']],
#   [['alias rf-mode-interdev-remote WORD', 'Alias name']],
#   [['alias rf-mode-interdevice WORD', 'Alias name']],
#   [['alias rlm-group WORD', 'Alias name']],
#   [['alias rlm-group-sc WORD', 'Alias name']],
#   [['alias roles WORD', 'Alias name']],
#   [['alias route-map WORD', 'Alias name']],
#   [['alias router WORD', 'Alias name']],
#   [['alias rsvp-local-if-policy WORD', 'Alias name']],
#   [['alias rsvp-local-policy WORD', 'Alias name']],
#   [['alias rsvp-local-subif-policy WORD', 'Alias name']],
#   [['alias saa WORD', 'Alias name']],
#   [['alias saa-dhcp WORD', 'Alias name']],
#   [['alias saa-dlsw WORD', 'Alias name']],
#   [['alias saa-dns WORD', 'Alias name']],
#   [['alias saa-echo WORD', 'Alias name']],
#   [['alias saa-frameRelay WORD', 'Alias name']],
#   [['alias saa-ftp WORD', 'Alias name']],
#   [['alias saa-http WORD', 'Alias name']],
#   [['alias saa-jitter WORD', 'Alias name']],
#   [['alias saa-pathEcho WORD', 'Alias name']],
#   [['alias saa-pathJitter WORD', 'Alias name']],
#   [['alias saa-slm-ctrlr-if WORD', 'Alias name']],
#   [['alias saa-slmAtm WORD', 'Alias name']],
#   [['alias saa-slmFrIf WORD', 'Alias name']],
#   [['alias saa-tcpConnect WORD', 'Alias name']],
#   [['alias saa-udpEcho WORD', 'Alias name']],
#   [['alias saa-voip WORD', 'Alias name']],
#   [['alias sampler WORD', 'Alias name']],
#   [['alias sat_init_config WORD', 'Alias name']],
#   [['alias sccpccmgroup WORD', 'Alias name']],
#   [['alias sccpplar WORD', 'Alias name']],
#   [['alias sctp-export WORD', 'Alias name']],
#   [['alias seczonecfg WORD', 'Alias name']],
#   [['alias seczonepaircfg WORD', 'Alias name']],
#   [['alias serviceflow WORD', 'Alias name']],
#   [['alias settlement_tag WORD', 'Alias name']],
#   [['alias sg-radius WORD', 'Alias name']],
#   [['alias sg-tacacs+ WORD', 'Alias name']],
#   [['alias signaling-class WORD', 'Alias name']],
#   [['alias sip-ua WORD', 'Alias name']],
#   [['alias sla-monitor-lspPing WORD', 'Alias name']],
#   [['alias sla-monitor-lspTrace WORD', 'Alias name']],
#   [['alias sla-slm WORD', 'Alias name']],
#   [['alias sla-slm-ctrlr-if WORD', 'Alias name']],
#   [['alias sla-slmAtm WORD', 'Alias name']],
#   [['alias sla-slmFrIf WORD', 'Alias name']],
#   [['alias sla-slmfr WORD', 'Alias name']],
#   [['alias source-group WORD', 'Alias name']],
#   [['alias srst-video WORD', 'Alias name']],
#   [['alias stcappfac WORD', 'Alias name']],
#   [['alias stcappfsd WORD', 'Alias name']],
#   [['alias subinterface WORD', 'Alias name']],
#   [['alias tablemap WORD', 'Alias name']],
#   [['alias tdm-conn WORD', 'Alias name']],
#   [['alias telephony-service WORD', 'Alias name']],
#   [['alias telephony-service-video WORD', 'Alias name']],
#   [['alias template template',
#     'peer-policy template peer-session WORD Alias name']],
#   [['alias template template',
#     'peer-policy template peer-session WORD Alias name']],
#   [['alias template template',
#     'peer-policy template peer-session WORD Alias name']],
#   [['alias tidp-group WORD', 'Alias name']],
#   [['alias tidp-keyset WORD', 'Alias name']],
#   [['alias tms-consumer WORD', 'Alias name']],
#   [['alias tms-controller WORD', 'Alias name']],
#   [['alias top-talkers WORD', 'Alias name']],
#   [['alias tracking-config WORD', 'Alias name']],
#   [['alias trange WORD', 'Alias name']],
#   [['alias translation-profile WORD', 'Alias name']],
#   [['alias translation-rule WORD', 'Alias name']],
#   [['alias trunk-group WORD', 'Alias name']],
#   [['alias vc-class WORD', 'Alias name']],
#   [['alias vc-group WORD', 'Alias name']],
#   [['alias view WORD', 'Alias name']],
#   [['alias vm-integration WORD', 'Alias name']],
#   [['alias voice-cause-code WORD', 'Alias name']],
#   [['alias voice-register-dialplan WORD', 'Alias name']],
#   [['alias voice-register-dn WORD', 'Alias name']],
#   [['alias voice-register-global WORD', 'Alias name']],
#   [['alias voice-register-pool WORD', 'Alias name']],
#   [['alias voice-register-temp WORD', 'Alias name']],
#   [['alias voice-service WORD', 'Alias name']],
#   [['alias voice-service-h323 WORD', 'Alias name']],
#   [['alias voice-service-session WORD', 'Alias name']],
#   [['alias voice-service-sip WORD', 'Alias name']],
#   [['alias voice-uri-class WORD', 'Alias name']],
#   [['alias voicecard WORD', 'Alias name']],
#   [['alias voicecl-cptone WORD', 'Alias name']],
#   [['alias voicecl-cptone-dt WORD', 'Alias name']],
#   [['alias voicecl-dt-detect WORD', 'Alias name']],
#   [['alias voiceclass WORD', 'Alias name']],
#   [['alias voicednismaps WORD', 'Alias name']],
#   [['alias voiceport WORD', 'Alias name']],
#   [['alias voipdialpeer WORD', 'Alias name']],
#   [['alias voipdpcor WORD', 'Alias name']],
#   [['alias voipdpcorlist WORD', 'Alias name']],
#   [['alias vpdn-group WORD', 'Alias name']],
#   [['alias vpdn-template WORD', 'Alias name']],
#   [['alias webvpn WORD', 'Alias name']],
#   [['alias webvpn-acl WORD', 'Alias name']],
#   [['alias webvpn-cifs-url WORD', 'Alias name']],
#   [['alias webvpn-group-policy WORD', 'Alias name']],
#   [['alias webvpn-nbnslist WORD', 'Alias name']],
#   [['alias webvpn-port-fwd WORD', 'Alias name']],
#   [['alias webvpn-sso-server WORD', 'Alias name']],
#   [['alias webvpn-time-range WORD', 'Alias name']],
#   [['alias webvpn-url WORD', 'Alias name']],
#   [['alias x25-profile WORD', 'Alias name']],
#   [['alias xconnect-cem-config WORD', 'Alias name']],
#   [['alias xconnect-conn-config WORD', 'Alias name']],
#   [['alias xconnect-dlci-config WORD', 'Alias name']],
#   [['alias xconnect-if-config WORD', 'Alias name']],
#   [['alias xconnect-pvc-config WORD', 'Alias name']],
#   [['alias xconnect-pvp-config WORD', 'Alias name']],
#   [['alias xconnect-subif-config WORD', 'Alias name']],
#   [['alias xml-app WORD', 'Alias name']],
#   [['alias xml-transport WORD', 'Alias name']]]]

# %%
# # Test 2

# device.enable()
# # device.send_config_set('?').split('\n')[4:-4]
# counter_1 = 0
# for no_layers in range(3):
#     counter_1 += 1
#     if counter_1 == 1:
#         conf_terminal_cmd_layer_1 = []
#         conf_terminal_cmd_layer_1 = device.send_config_set('?').split('\n')[4:-4][8:11] # remove first line and the last 2 lines (hostname)
#         conf_terminal_cmd_desc_layer_1 = [" ".join(i.split()).split(" ", 1) 
#                                                      for i in conf_terminal_cmd_layer_1]
#     else:
# #         device.enable()
#         exec(f"conf_terminal_cmd_desc_layer_{str(counter_1)} = []") # dyamically create a list name for the respective layer 
#         for cmd_desc_1 in vars()["conf_terminal_cmd_desc_layer_"+str( counter_1-1 )]:
#             counter_2 = 0
#             if counter_1 == 2:
#                 help_cmd_output = device.send_config_set( cmd_desc_1[0]+" ?" "\x03" )[87:].split('\n')[1:-4]
#                 try:
#                     vars()["conf_terminal_cmd_desc_layer_"+str( counter_1 )].append([[cmd_desc_1[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                                   " ".join(j.split()).split(" ", 1)[1]] 
#                                                                  for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])
                
#                 except IndexError:
#                     pass
                
#             elif counter_1 == 3:
#                 one_conf_terminal_cmd_desc = []
#                 for k in cmd_desc_1:            
#                     counter_2 += 1
#                     print(k[0])
#                     if k[0].split(" ")[-1] == "A.B.C.D" or re.match("<\d*-\d*>", k[0].split(" ")[-1]):
#                         try: # if it is a number range at the end of the command (e.g. <100-200>), convert it to an integer before adding ?
#     #                             print(k[0].split()[:-1][0] + " " + genenrate_number_ip(k[0].split()[-1]) + " ?")
#     #                             print(k[0])
#                             help_cmd_output = device.send_config_set(k[0].split()[:-1][0] + " " + genenrate_number_ip(k[0].split()[-1]) + " ?" "\x03")[87:].split('\n')[1:-4]
# #                             print(k[0].split()[:-1][0])
# #                             print(genenrate_number_ip(k[0].split()[-1]))
#                             print('1 {}'.format(help_cmd_output))
#                             one_conf_terminal_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                                           " ".join(j.split()).split(" ", 1)[1]] 
# #                                                                and [k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
# #                                                                           " ".join(j.split()).split(" ", 1)[1]] is not None
# #                                                                else []
#                                                                for j in help_cmd_output
#                                                               if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1 ] and j[0].strip() != "<ctr>")
# #                             print('1 is {}'.format(one_conf_terminal_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
# #                                                                           " ".join(j.split()).split(" ", 1)[1]] 
# #                                                                          for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])))
# #                     except (ValueError, IndexError) as e:
#                         except TypeError: # if not a range:
#                             print('error 1 {}'.format(k[0]))
#                             pass
                    
#                     else:
#                         try:
#                             help_cmd_output = device.send_config_set(k[0]+" ?" "\x03")[87:].split('\n')[1:-4]
#                             print('2 {}'.format(help_cmd_output))
#                             one_conf_terminal_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                                       " ".join(j.split()).split(" ", 1)[1]] 
#                                                                      for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1] and j.strip() != "<ctr>")

# #                             print('2 is {}'.format([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
# #                                                                       " ".join(j.split()).split(" ", 1)[1]] 
# #                                                                      for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1]))
#                         except IndexError:
#                             print('error 2 {}'.format(k[0]))
#                             pass
#                     if counter_2 == len(cmd_desc_1):
#                         vars()["conf_terminal_cmd_desc_layer_"+str(counter_1)].append(one_conf_terminal_cmd_desc)

# %%
# device.enable()
# for k in conf_terminal_cmd_desc_layer_2[3]:            
#         counter_2 += 1
# #                     try: # if it is a number range at the end of the command, convert it to an integer before adding ?
#         x = int(k[0].split(" ")[-1].split('-')[0][1:])
#         print(x)
#         y = int(k[0].split(" ")[-1].split('-')[1][:-1])
#         print(k[0].split()[:-1][0])
#         print(y)
#         z = str(1)
#         print(z)
#         help_cmd_output = device.send_config_set(k[0].split()[:-1][0] + " " + z + " ?" "\x03").split('\n')[3:]
#         one_conf_terminal_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                       " ".join(j.split()).split(" ", 1)[1]] 
#                                                      for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])

# %%
# one_conf_terminal_cmd_desc = []
# device.enable()
# for k in conf_terminal_cmd_desc_layer_2[2][:5]:
# #     try:
#     x = int(k[0].split(" ")[-1].split('-')[0][1:])
#     y = int(k[0].split(" ")[-1].split('-')[1][:-1])
# #                         if type(x) == int and type(y) == int:
#     z = str(random.randint(x,y))
# #     print(k[0].split()[:-1])
#     help_cmd_output = device.send_config_set(k[0].split()[:-1][0] + " " + z + " ?" "\x03").split('\n')[3:]
#     one_conf_terminal_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                               " ".join(j.split()).split(" ", 1)[1]] 
#                                                              for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])
# #     except:
# #         print(k[0])

# %%
# ## store output of '?' command in xec mode (in  form of [command, command description]) into a list

# device.enable()
# counter_1 = 0
# for no_layers in range(3):
#     counter_1 += 1
#     if counter_1 == 1:
#         xec_cmd_layer_1 = []
#         xec_cmd_layer_1 = device.send_command("?").split('\n')[2:-2] # remove first line and the last 2 lines (hostname)
#         xec_cmd_desc_layer_1 = [" ".join(i.split()).split(" ", 1) 
#                                                      for i in xec_cmd_layer_1]
    
    
#     else:
#         exec(f"xec_cmd_desc_layer_{str(counter_1)} = []") # dyamically create a list name for the respective layer 
#         for cmd_desc_1 in vars()["xec_cmd_desc_layer_"+str(counter_1-1)]:
#             counter_2 = 0
#             if counter_1 == 2:
#                 help_cmd_output = device.send_command(cmd_desc_1[0]+" ?" "\x03").split('\n')
#                 try:
#                     vars()["xec_cmd_desc_layer_"+str(counter_1)].append([[cmd_desc_1[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                                   " ".join(j.split()).split(" ", 1)[1]] 
#                                                                  for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])
#                 except IndexError:
#                     pass
            
#             elif counter_1 == 3:
#                 one_xec_cmd_desc = []
#                 for k in cmd_desc_1:            
#                     counter_2 += 1
#                     help_cmd_output = device.send_command(k[0]+" ?" "\x03").split('\n')
#                     try:
#                         one_xec_cmd_desc.append([[k[0] + " " + " ".join(j.split()).split(" ", counter_1-1)[0], 
#                                                                   " ".join(j.split()).split(" ", 1)[1]] 
#                                                                  for j in help_cmd_output if len(" ".join(j.split()).split(" ", counter_1-1)) > counter_1-1])
                    

#                     except IndexError:
#                         pass
#                     if counter_2 == len(cmd_desc_1):
#                         vars()["xec_cmd_desc_layer_"+str(counter_1)].append(one_xec_cmd_desc)

# %%
def connect_mongodb_database(db_address, db_name, collection_name):
    try:
        myclient = pymongo.MongoClient(db_address) # MongoDB instance running on GC
        print("Connected successfully!!!") 
    except:   
        print("Could not connect to MongoDB") 

    try:
        mydb = myclient[db_name]
        print("Connected to {}".format(db_name))   

        if mydb.collection_name.count() != 0:
            mydb.confcommands.remove()
            print('{} documents removed'.format(mydb.collection_name.count()))
    except:
        print("Could not connect to {}".format(db_name))
# Out:
# Connected successfully!!!
# Connected to DB
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
# {'n': 0, 'ok': 1.0}

# %%
connect_mongodb_database('mongodb://ehsan:ehgh1363@10.128.0.2:27017/', 'commandsdatabase', 'xeccommands')

# %%
# for i,j in enumerate(xec_cmd_desc_layer_1):
#     print("layer 1 {} and {}".format(i,j))
#     for k, h in enumerate(xec_cmd_desc_layer_2[i]):
#         print("layer 2 {}".format(h))
#         print("layer 3 {}".format([t for t in xec_cmd_desc_layer_3[i][k]]))

# %%
# Conver the list to dict to prepare for MongoDB

list_of_dicts = []
# cmd_dict = {}

for i, j in enumerate(xec_cmd_desc_layer_1):
    try:
        cmd_dict = [
            {
                "cmd":
                {
                    "name": j[0],
                    "desc": j[1],
                    "c1": 
                    [
                        {
                            "_id": str(k+1), 
                            "name": l[0], 
                            "desc": l[1],
                            "c2": 
                                [
                                    {
                                    "_id": str(m+1), 
                                    "n": n[0], 
                                    "d": n[1]
                                    }
                                for m, n in enumerate(xec_cmd_desc_layer_3[i][k]) if len(l) > 0
                                ]

                        }
                        for k, l in enumerate(xec_cmd_desc_layer_2[i]) if len(l) > 0
                    ]
                }
            }
        ]
    #     cmd_dict = {j[0].replace('.', ''):j[1] for j in i}
        list_of_dicts.append(cmd_dict)
    except IndexError:
        cmd_dict = [
            {
                "cmd":
                {
                    "name": j[0],
                    "desc": j[1],
                    "c1": 
                    [
                        {
                            "_id": str(k+1), 
                            "name": l[0], 
                            "desc": l[1],

                        }
                        for k, l in enumerate(xec_cmd_desc_layer_2[i]) if len(l) > 0
                    ]
                }
            }
        ]
        list_of_dicts.append(cmd_dict)

# %%
# Insert all commands:descriptions into MongoDB
for i in list_of_dicts:
    mydb.xeccommands.insert_one(i[0])

# %%
# # Conver the list to dict to prepare for MongoDB

# list_of_dicts_conf_terminal = []
# # cmd_dict = {}

# for i, j in enumerate(conf_terminal_cmd_desc_layer_1):
#     try:
#         cmd_dict = [
#             {
#                 "cmd":
#                 {
#                     "name": j[0],
#                     "desc": j[1],
#                     "c1": 
#                     [
#                         {
#                             "_id": str(k+1), 
#                             "name": l[0], 
#                             "desc": l[1],
#                             "c2": 
#                                 [
#                                     {
#                                     "_id": str(m+1), 
#                                     "n": n[0], 
#                                     "d": n[1]
#                                     }
#                                 for m, n in enumerate(conf_terminal_cmd_desc_layer_3[i][k]) if len(l) > 0
#                                 ]

#                         }
#                         for k, l in enumerate(conf_terminal_cmd_desc_layer_2[i]) if len(l) > 0
#                     ]
#                 }
#             }
#         ]
#     #     cmd_dict = {j[0].replace('.', ''):j[1] for j in i}
#         list_of_dicts_conf_terminal.append(cmd_dict)
#     except IndexError:
#         cmd_dict = [
#             {
#                 "cmd":
#                 {
#                     "name": j[0],
#                     "desc": j[1],
#                     "c1": 
#                     [
#                         {
#                             "_id": str(k+1), 
#                             "name": l[0], 
#                             "desc": l[1],

#                         }
#                         for k, l in enumerate(conf_terminal_cmd_desc_layer_2[i]) if len(l) > 0
#                     ]
#                 }
#             }
#         ]
#         list_of_dicts_conf_terminal.append(cmd_dict)

# %%
# # Insert all commands:descriptions into MongoDB
# for i in list_of_dicts_conf_terminal:
#     mydb.confcommands.insert_one(i[0])

# %%
# a=[{
# "_id": 'ObjectId1',
# "command": {
# 			"name": "command name",
# 			"desc": "command desc",
# 			"sub_command_one": 
# 				[{
# 				"ID": "id1",
# 				"name": "sub command one name",
# 				"desc": "sub command one desc",
# 				"sub_command_two": 
# 					[{
# 					"ID": "id1",
# 					"name": "sub command one name",
# 					"desc": "sub command one desc",
# 					},
# 					{
# 					"ID": "id2",
# 					"name": "sub command one name",
# 					"desc": "sub command one desc"
# 					}]
# 				},		
# 				{
# 				"ID": "id2",
# 				"name": "sub command 1 name",
# 				"desc": "sub command 1 desc",
# 				"sub_command_two": 
# 					{
# 					"ID": "id1",
# 					"name": "sub command 2 name",
# 					"desc": "sub command 2 desc",
# 					"sub_command_three":
# 						{
# 						"ID":"id1",
# 						"name": "sub command 3",
# 						"desc": "sub command 3 desc",
# 						}
# 					}
# 				}]
			
# 			}},
# {"_id": "ObjectId2",
# "command": {
# 			"name": "command name",
# 			"desc": "command desc",
# 			"sub_command_one": "222"
# }}]

# %%
desc_list = []
cmd_list = []
for i in mydb.xeccommands.find({}):
    desc_list.append(i["cmd"]["desc"])
    cmd_list.append(i["cmd"]["name"])
    for j in i["cmd"]["c1"]:
        desc_list.append(j["desc"])
        cmd_list.append(j["name"])        
        try:
            for k in j["c2"]:
                desc_list.append(k["d"])
                cmd_list.append(k["n"])
#                 desc_word.append(nltk.word_tokenize(k['d'].lower())[0])
        except KeyError:
            pass

# %%
# def automate():
# #     f=open('/home/ehsan_ghoreishi/gns3/yoda/modules/chatbot.txt','r',errors = 'ignore')
# #     raw = desc
# #     raw=f.read()
# #     raw=raw.lower()# converts to lowercase
#     try:
#         nltk.data.find('tokenizers/punkt')
#     except LookupError:
#         nltk.download('punkt')
#     try:
#         nltk.data.find(os.path.join("corpora", 'wordnet'))
#     except LookupError:
#         nltk.download('wordnet') # first-time use only
# #     sent_tokens = nltk.sent_tokenize(raw)# converts to list of sentences 
# #     word_tokens = nltk.word_tokenize(raw)# converts to list of words
#     word_tokens = desc_word
#     sent_tokens = desc_sent

#     lemmer = nltk.stem.WordNetLemmatizer()
#     def LemTokens(tokens):
#         return [lemmer.lemmatize(token) for token in tokens]
#     remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
#     def LemNormalize(text):
#         return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))


#     # Generating response
#     def response(user_response):
#         robo_response=''
#         sent_tokens.append(user_response)
#         TfidfVec = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english')
#         tfidf = TfidfVec.fit_transform(sent_tokens)
#         vals = cosine_similarity(tfidf[-1], tfidf)
#         idx=vals.argsort()[0][-2]
#         flat = vals.flatten()
#         flat.sort()
#         req_tfidf = flat[-2]
#         if(req_tfidf==0):
#             robo_response=robo_response+"I am sorry! I don't understand you"
#             return robo_response
#         else:
#             robo_response = robo_response+sent_tokens[idx]
#             return robo_response


#     flag=True
#     print("Yoda: My name is Robo. I will answer your queries about Chatbots. If you want to exit, type Bye!")

#     while(flag==True):
#         user_response = input()
#         user_response=user_response.lower()
#         if(user_response!='bye'):
#             if(user_response=='thanks' or user_response=='thank you' ):
#                 flag=False
#                 print("Yoda: You are welcome..")
#         #    else:
#          #       if(greeting(user_response)!=None):
#           #          print("ROBO: "+greeting(user_response))
#             else:
#                 print("Yoda: ",end="")
#                 print(response(user_response))
#                 sent_tokens.remove(user_response)
#         else:
#             flag=False
#             print("Yoda: Bye! take care..")
